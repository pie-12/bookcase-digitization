# %% [markdown]
# # 🚀 Bookcase Digitization - CHẠY NHẬN DIỆN THỰC TẾ
# Notebook này đã được tối ưu để vượt qua mọi lỗi thư viện của Colab (Numpy 2.0, OpenCV).

# %%
# 1. FIX LỖI NUMPY VÀ OPENCV (CHẠY ĐẦU TIÊN)
# !pip install "numpy<2" --force-reinstall -q
# !pip install opencv-python-headless==4.8.0.74 -q
print("✅ Đã vá lỗi Numpy 2.0 và OpenCV")

# %%
# 2. Clone dự án và cài đặt thư viện lõi
import os
# %cd /content/
# !rm -rf bookcase-digitization
# !git clone https://github.com/pie-12/bookcase-digitization.git
# %cd bookcase-digitization

# Cài các thư viện AI (Ép không check dependency để tránh lỗi vòng lặp)
# !pip install -q craft-text-detector vietocr==0.3.5 --no-deps
# !pip install -q albumentations==1.4.2 einops gdown prefetch-generator shapely scikit-image
# !git clone https://github.com/ultralytics/yolov5

print("✅ Môi trường AI đã sẵn sàng!")

# %% [markdown]
# ### 3. Tải Model của bạn lên
# Chạy Cell này, sau đó bấm nút chọn file `best.pt` từ máy tính của bạn.

# %%
from google.colab import files
uploaded = files.upload()
for fn in uploaded.keys():
  print('Đã tải lên file "{name}"'.format(name=fn))
  if fn == 'best.pt':
    # !mv best.pt last.pt

# %%
# 4. Chạy pipeline thật
# !python run_inference.py

# Hiển thị file CSV kết quả
import pandas as pd
if os.path.exists('ket_qua_cuoi_cung.csv'):
  df = pd.read_csv('ket_qua_cuoi_cung.csv')
  display(df)
